# %% [markdown]
# # Data Cleaning and EDA
#
# Hi all! Kyra here! I made this file for us to do our data cleaning and EDA in. I thought it would be helpful to have a separate notebook to work on this stuff since it can get kinda long and messy. Then we can either paste the necessary cells into checkpoint/final/etc OR we can just save pictures of the outputs and redirect readers to view this notebook if they want to see the code (I have done this in the past and it makes the final much more readable and nice to look at).
#
# Anyhow, I have just added the dataset for injuries to our repo and I'm going to do some things to get a quick look at it, but I wanted y'all to be able to see what I was doing and possibly do some exploration of your own too. (3/2)

# %%
#setup
import numpy as np
import pandas as pd

# %%
#read injury data from csv
injuries = pd.read_csv('injuries_2010-2020.csv')
injuries.head()
# Out:
#          Date     Team Acquired   Relinquished  \
# 0  2010-10-03    Bulls      NaN  Carlos Boozer
# 1  2010-10-06  Pistons      NaN  Jonas Jerebko
# 2  2010-10-06  Pistons      NaN  Terrico White
# 3  2010-10-08  Blazers      NaN     Jeff Ayres
# 4  2010-10-08     Nets      NaN    Troy Murphy
#
#                                                Notes
# 0  fractured bone in right pinky finger (out inde...
# 1      torn right Achilles tendon (out indefinitely)
# 2  broken fifth metatarsal in right foot (out ind...
# 3          torn ACL in right knee (out indefinitely)
# 4             strained lower back (out indefinitely)

# %%
injuries.shape #(27105, 5)
# Out:
# (27105, 5)

# %%
#Number of non "NaN" entries in acquired column
injuries[injuries['Acquired'].apply(lambda x: isinstance(x, str))].shape #(9452, 5)
#Number of non "NaN" entries in Relinquished column
injuries[injuries['Relinquished'].apply(lambda x: isinstance(x, str))].shape #(17560, 5)

#NOTE: The NaN entries don't seem to be np.nan, but float("NaN"). This may have just been my mistake due to some idiosyncrasy
#in the way I was doing things, but if it wasn't, we'll have to be a little crafty about how we fix it.
# Out:
# (17560, 5)

# %%
#Number of unique players we have injuries recorded for
injuries['Relinquished'].nunique() #1156
#Number of unique players who came back after injuries
injuries['Acquired'].nunique() #1111
# Out:
# 1156

# %% [markdown]
# There are 27,105 rows in our original dataframe. Rows refer to a player either being acquired (9452 rows total) or relinquished (17560). There are 1156 unique players in the relinquished column, and 1111 unique players in the acquired column. Thus, some players repeat, which is to be expected since someone can be injured multiple times.
#
# However, taking player "Jonas Jerebko" as an example (see below), we can see that we sometimes have multiple entries for the same injury (look at rows 1, 5, and 75, where 5 reports surgery to address the injury reported in 1 and 75 moves him from out indefinitely to IL as he recovers from this surgery).
#
# My gut reaction would be to just combine these three rows together into one entry based on the year (all of this happens in 2010), but later in 2017, he has two separate illnesses, one in January and one in March. We could get around this by rephrasing our question, or just deciding our ground truth meant that the player had been placed on IL or was out indefinitely at some point during the year, but that changes things a little bit. We'll need to make a firm decision, since I doubt we have the time to do this kind of investigation for each of 1156 unique players in the dataset.
#
# Also, there's no "acquired" entry after Jerebko's recovery from surgery, so we'll have to take a look at that.

# %%
injuries[(injuries['Relinquished'] == 'Jonas Jerebko') | (injuries['Acquired'] == 'Jonas Jerebko')]
# Out:
#              Date     Team       Acquired   Relinquished  \
# 1      2010-10-06  Pistons            NaN  Jonas Jerebko
# 5      2010-10-08  Pistons            NaN  Jonas Jerebko
# 75     2010-10-27  Pistons            NaN  Jonas Jerebko
# 15112  2016-03-16  Celtics            NaN  Jonas Jerebko
# 15198  2016-03-21  Celtics  Jonas Jerebko            NaN
# 17397  2017-01-21  Celtics            NaN  Jonas Jerebko
# 17455  2017-01-24  Celtics  Jonas Jerebko            NaN
# 18026  2017-03-06  Celtics            NaN  Jonas Jerebko
# 18051  2017-03-08  Celtics  Jonas Jerebko            NaN
#
#                                                    Notes
# 1          torn right Achilles tendon (out indefinitely)
# 5           surgery to repair torn right Achilles tendon
# 75     placed on IL recovering from surgery to repair...
# 15112                  placed on IL with sore left ankle
# 15198                                  activated from IL
# 17397                          placed on IL with illness
# 17455                                  activated from IL
# 18026                                          flu (DTD)
# 18051                                 returned to lineup

# %%
#It seemed that a lot of the acquired messages were very similar when I was scrolling. I was right.
#Most are either activated from IL or returned to lineup (~ 97 %)

injuries[injuries['Acquired'].apply(lambda x: isinstance(x, str))]['Notes'].value_counts(normalize = True)

#In cleaning, we should make them all the same, 
#except for the few that might warrant keeping distinct (ex. 'torn ACL in right knee (out for season)')

#Below I have code for checking out one such example, but I think a Google might help too.
injuries[injuries['Notes'] == 'surgery on right knee to repair torn lateral meniscus (out for season)']
injuries[(injuries['Acquired'] == 'Russell Westbrook') | (injuries['Relinquished'] == 'Russell Westbrook')]
#side note: This poor guy!
# Out:
#              Date     Team           Acquired       Relinquished  \
# 7405   2013-04-26  Thunder                NaN  Russell Westbrook
# 7413   2013-04-27  Thunder                NaN  Russell Westbrook
# 7414   2013-04-27  Thunder  Russell Westbrook                NaN
# 7498   2013-10-01  Thunder                NaN  Russell Westbrook
# 7585   2013-10-30  Thunder                NaN  Russell Westbrook
# 7640   2013-11-03  Thunder  Russell Westbrook                NaN
# 7957   2013-11-24  Thunder                NaN  Russell Westbrook
# 8004   2013-11-27  Thunder  Russell Westbrook                NaN
# 8480   2013-12-27  Thunder                NaN  Russell Westbrook
# 8482   2013-12-27  Thunder                NaN  Russell Westbrook
# 9283   2014-02-20  Thunder  Russell Westbrook                NaN
# 9638   2014-03-16  Thunder                NaN  Russell Westbrook
# 9685   2014-03-20  Thunder                NaN  Russell Westbrook
# 9758   2014-03-24  Thunder                NaN  Russell Westbrook
# 9966   2014-04-04  Thunder                NaN  Russell Westbrook
# 10046  2014-04-08  Thunder                NaN  Russell Westbrook
# 10244  2014-04-14  Thunder                NaN  Russell Westbrook
# 10329  2014-04-16  Thunder  Russell Westbrook                NaN
# 10533  2014-10-30  Thunder                NaN  Russell Westbrook
# 10555  2014-11-01  Thunder                NaN  Russell Westbrook
# 10920  2014-11-28  Thunder  Russell Westbrook                NaN
# 12133  2015-02-28  Thunder                NaN  Russell Westbrook
# 12179  2015-03-04  Thunder  Russell Westbrook                NaN
# 15470  2016-04-06  Thunder                NaN  Russell Westbrook
# 15613  2016-04-12  Thunder                NaN  Russell Westbrook
# 18715  2017-04-11  Thunder                NaN  Russell Westbrook
# 21049  2018-02-08  Thunder                NaN  Russell Westbrook
# 21123  2018-02-13  Thunder  Russell Westbrook                NaN
# 22278  2018-10-16  Thunder                NaN  Russell Westbrook
# 22366  2018-10-21  Thunder  Russell Westbrook                NaN
# 22565  2018-11-06  Thunder                NaN  Russell Westbrook
# 22713  2018-11-17  Thunder  Russell Westbrook                NaN
# 25546  2019-12-14  Thunder                NaN  Russell Westbrook
# 25563  2019-12-16  Rockets  Russell Westbrook                NaN
# 25745  2019-12-29  Thunder                NaN  Russell Westbrook
# 25777  2019-12-31  Rockets  Russell Westbrook                NaN
# 25900  2020-01-08  Rockets                NaN  Russell Westbrook
# 25910  2020-01-09  Thunder  Russell Westbrook                NaN
# 25979  2020-01-14  Thunder                NaN  Russell Westbrook
# 25991  2020-01-15  Rockets  Russell Westbrook                NaN
# 26161  2020-01-27  Rockets                NaN  Russell Westbrook
# 26188  2020-01-29  Thunder  Russell Westbrook                NaN
# 26285  2020-02-04  Rockets                NaN  Russell Westbrook
# 26318  2020-02-06  Rockets  Russell Westbrook                NaN
# 26337  2020-02-07  Rockets                NaN  Russell Westbrook
# 26371  2020-02-09  Rockets  Russell Westbrook                NaN
# 26497  2020-02-24  Rockets                NaN  Russell Westbrook
# 26516  2020-02-26  Rockets  Russell Westbrook                NaN
# 26879  2020-08-06  Rockets                NaN  Russell Westbrook
# 26957  2020-08-11  Rockets  Russell Westbrook                NaN
# 26985  2020-08-12  Rockets                NaN  Russell Westbrook
# 27076  2020-08-28  Rockets  Russell Westbrook                NaN
#
#                                                    Notes
# 7405   torn lateral meniscus in right knee (out indef...
# 7413   placed on IL with torn lateral meniscus in rig...
# 7414   surgery on right knee to repair torn lateral m...
# 7498   arthroscopic surgery on right knee (out indefi...
# 7585   placed on IL recovering from arthroscopic surg...
# 7640                                   activated from IL
# 7957                       placed on IL with knee injury
# 8004                                   activated from IL
# 8480   arthroscopic surgery on right knee (out indefi...
# 8482   placed on IL recovering from arthroscopic surg...
# 9283                                   activated from IL
# 9638                                          rest (DNP)
# 9685                            rest / knee injury (DNP)
# 9758                            rest / knee injury (DNP)
# 9966                            rest / knee injury (DNP)
# 10046                                  knee injury (DNP)
# 10244                              placed on IL for rest
# 10329                                  activated from IL
# 10533                         fractured right hand (DTD)
# 10555  surgery on right hand to repair fracture (out ...
# 10920                                 returned to lineup
# 12133    surgery on right cheek to repair fracture (DTD)
# 12179                                 returned to lineup
# 15470                                         rest (DTD)
# 15613                                         rest (DTD)
# 18715                                         rest (DTD)
# 21049              placed on IL with sprained left ankle
# 21123                                  activated from IL
# 22278                            right knee injury (DTD)
# 22366                                 returned to lineup
# 22565                          sprained left ankle (DTD)
# 22713                                 returned to lineup
# 25546                                       placed on IL
# 25563                                  activated from IL
# 25745                                       placed on IL
# 25777                                  activated from IL
# 25900                                       placed on IL
# 25910                                  activated from IL
# 25979                                       placed on IL
# 25991                                  activated from IL
# 26161                                       placed on IL
# 26188                                  activated from IL
# 26285              placed on IL with sprained left thumb
# 26318                                  activated from IL
# 26337                                       placed on IL
# 26371                                  activated from IL
# 26497                            left thumb injury (DTD)
# 26516                                 returned to lineup
# 26879         placed on IL with bruised right quadriceps
# 26957                                  activated from IL
# 26985        placed on IL with strained right quadriceps
# 27076                                  activated from IL

# %% [markdown]
# **To Do:** Learn basketball jargon for referring to injuries. Specifically, this acquired/relinquished business, "IL", "DTD", and "out indefinitely" (cuz a lot of these "out indefinitely" guys come back not that too long later).

# %%
#Getting bored/overwhelmed so switching focus to teams
print(injuries['Team'].value_counts())
len(injuries['Team'].value_counts())

#Bullets is sus (with only one entry)
#Bobcats end in 2013, Hornets move from New Orleans to Charlotte and New Orleans becomes Pelicans
# Out:
# Spurs           1163
# Bucks           1068
# Warriors        1060
# Rockets         1058
# Raptors         1044
# Celtics         1040
# Nets            1024
# Heat            1023
# Cavaliers       1001
# Mavericks        992
# Hawks            975
# Nuggets          966
# Lakers           959
# Knicks           943
# 76ers            910
# Grizzlies        875
# Wizards          875
# Timberwolves     860
# Jazz             841
# Magic            834
# Pacers           831
# Bulls            791
# Suns             733
# Kings            728
# Hornets          719
# Clippers         718
# Thunder          717
# Pistons          714
# Blazers          695
# Pelicans         576
# Bobcats          369
# Bullets            1
# Name: Team, dtype: int64
# 32
